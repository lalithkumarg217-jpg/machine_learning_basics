# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([1,2,3,4,5])
y=np.array([10,20,30,40,50])

# %%
def gradient_descent(x,y):
    m_current=b_current=0
    iterations=1000
    n=len(x)
    m_history =[]
    b_history=[]
    learning_rate=0.01
    for i in range(iterations):
        y_pred=(m_current*x)+b_current
        md=-(2/n)*sum(x*(y-y_pred))
        bd=-(2/n)*sum(y-y_pred)
        cost_function=(1/n)*sum(np.pow(y-y_pred,2))
        m_current=m_current-learning_rate*md
        b_current-=learning_rate*mb
        m_history.append(m_current)
        b_history.append(b_current)
        print(f"m:{m_current}")
        print(f"b:{b_current}")
        print(f"iteration:{i}")
        print(f"m_current*x+b_current:{m_current*x+b_current}")
        print(f"cost:{cost_function}")
        #plotting the graph between values  of x and m*x+b
        plt.plot(x,y_pred)
        plt.xlabel(x)

# %%
gradient_descent(x,y)
# Out:
# m:2.2
# b:0.6
# iteration:0
# m_current*x+b_current:[ 2.8  5.   7.2  9.4 11.6]
# cost:1100.0
# m:3.88
# b:1.056
# iteration:1
# m_current*x+b_current:[ 4.936  8.816 12.696 16.576 20.456]
# cost:641.5200000000001
# m:5.16304
# b:1.40208
# iteration:2
# m_current*x+b_current:[ 6.56512 11.72816 16.8912  22.05424 27.21728]
# cost:374.337216
# m:6.143046399999999
# b:1.664256
# iteration:3
# m_current*x+b_current:[ 7.8073024 13.9503488 20.0933952 26.2364416 32.379488 ]
# cost:218.6330015232
# m:6.891720832
# b:1.862388096
# iteration:4
# m_current*x+b_current:[ 8.75410893 15.64582976 22.53755059 29.42927142 36.32099226]
# cost:127.89300080848903
# m:7.4637989632
# b:2.01163708416
# iteration:5
# m_current*x+b_current:[ 9.47543605 16.93923501 24.40303397 31.86683294 39.3306319 ]
# cost:75.01094993940512
# m:7.9010649662464
# b:2.1235764046848002
# iteration:6
# m_current*x+b_current:[10.02464137 17.92570634 25.8267713  33.72783627 41.62890124]
# cost:44.19066009701555
# m:8.235416089391105
# b:2.20704097861632
# iteration:7
# m_current*x+b_current:[10.44245707 18.67787316 26.91328925 35.14870534 43.38412143]
# cost:26.226894305761874
# m:8.491202091008082
# b:2.2687751936805274
# iteration:8
# m_current*x+b_current:[10.75997728 19.25117938 27.74238147 36.23358356 44.72478565]
# cost:15.755296029144052
# m:8.687011119365472
# b:2.313927564346432
# iteration:9
# m_current*x+b_current:[11.00093868 19.6879498  28.37496092 37.06197204 45.74898316]
# cost:9.649783702234858
# m:8.837033019244283
# b:2.346428345897575
# iteration:10
# m_current*x+b_current:[11.18346137 20.02049438 28.8575274  37.69456042 46.53159344]
# cost:6.0886316049276274
# m:8.952100054256686
# b:2.3692777978249664
# iteration:11
# m_current*x+b_current:[11.32137785 20.27347791 29.22557796 38.17767801 47.12977807]
# cost:4.010228030111583
# m:9.040481374450717
# b:2.3847662386130657
# iteration:12
# m_current*x+b_current:[11.42524761 20.46572899 29.50621036 38.54669174 47.58717311]
# cost:2.795918087693844
# m:9.108489497754775
# b:2.3946420313737615
# iteration:13
# m_current*x+b_current:[11.50313153 20.61162103 29.72011052 38.82860002 47.93708952]
# cost:2.085180192182484
# m:9.1609432863663
# b:2.4002398208809996
# iteration:14
# m_current*x+b_current:[11.56118311 20.72212639 29.88306968 39.04401297 48.20495625]
# cost:1.667920069645433
# m:9.201521374112854
# b:2.402578427281402
# iteration:15
# m_current*x+b_current:[11.6040998  20.80562118 30.00714255 39.20866392 48.4101853 ]
# cost:1.42170503712758
# m:9.233031966171142
# b:2.4024355762890024
# iteration:16
# m_current*x+b_current:[11.63546754 20.86849951 30.10153147 39.33456344 48.56759541]
# cost:1.2751872480123176
# m:9.25761879903615
# b:2.400404946792954
# iteration:17
# m_current*x+b_current:[11.65802375 20.91564254 30.17326134 39.43088014 48.68849894]
# cost:1.1867885702061673
# m:9.27691836644062
# b:2.3969397199149256
# iteration:18
# m_current*x+b_current:[11.67385809 20.95077645 30.22769482 39.50461319 48.78153155]
# cost:1.1322791883795758
# m:9.292179942628788
# b:2.39238582353019
# iteration:19
# m_current*x+b_current:[11.68456577 20.97674571 30.26892565 39.56110559 48.85328554]
# cost:1.097539028289076
# m:9.304357205838643
# b:2.3870073105018585
# iteration:20
# m_current*x+b_current:[11.69136452 20.99572172 30.30007893 39.60443613 48.90879334]
# cost:1.074339473223788
# m:9.31417818192403
# b:2.381005731941503
# iteration:21
# m_current*x+b_current:[11.69518391 21.0093621  30.32354028 39.63771846 48.95189664]
# cost:1.057885157177546
# m:9.322198637984252
# b:2.374534926387231
# iteration:22
# m_current*x+b_current:[11.69673356 21.0189322  30.34113084 39.66332948 48.98552812]
# cost:1.045381443601049
# m:9.328842842044482
# b:2.367712309580431
# iteration:23
# m_current*x+b_current:[11.69655515 21.02539799 30.35424084 39.68308368 49.01192652]
# cost:1.0351996229318705
# m:9.33443467821987
# b:2.3606274928661537
# iteration:24
# m_current*x+b_current:[11.69506217 21.02949685 30.36393153 39.69836621 49.03280088]
# cost:1.026390431037122
# m:9.339221399439529
# b:2.3533488623156384
# iteration:25
# m_current*x+b_current:[11.69257026 21.03179166 30.37101306 39.71023446 49.04945586]
# cost:1.0184005518398132
# m:9.343391759823895
# b:2.345928601102954
# iteration:26
# m_current*x+b_current:[11.68932036 21.03271212 30.37610388 39.71949564 49.0628874 ]
# cost:1.0109074090784815
# m:9.34708985659646
# b:2.3384065234914613
# iteration:27
# m_current*x+b_current:[11.68549638 21.03258624 30.37967609 39.72676595 49.07385581]
# cost:1.0037228911176261
# m:9.350425696735751
# b:2.3308130016258444
# iteration:28
# m_current*x+b_current:[11.6812387  21.0316644  30.38209009 39.73251579 49.08294149]
# cost:0.9967372465274615
# m:9.353483263356335
# b:2.3231711997891824
# iteration:29
# m_current*x+b_current:[11.67665446 21.03013773 30.38362099 39.73710425 49.09058752]
# cost:0.989886389199495
# m:9.35632667343059
# b:2.315498779992019
# iteration:30
# m_current*x+b_current:[11.67182545 21.02815213 30.3844788  39.74080547 49.09713215]
# cost:0.9831328453805246
# m:9.35900487847634
# b:2.307809203986343
# iteration:31
# m_current*x+b_current:[11.66681408 21.02581896 30.38482384 39.74382872 49.1028336 ]
# cost:0.9764546505415237
# m:9.361555252972364
# b:2.300112727198036
# iteration:32
# m_current*x+b_current:[11.66166798 21.02322323 30.38477849 39.74633374 49.10788899]
# cost:0.9698388790166425
# m:9.364006333686563
# b:2.2924171574757333
# iteration:33
# m_current*x+b_current:[11.65642349 21.02042982 30.38443616 39.74844249 49.11244883]
# cost:0.9632778733914146
# m:9.366379910826975
# b:2.2847284343050247
# iteration:34
# m_current*x+b_current:[11.65110835 21.01748826 30.38386817 39.75024808 49.11662799]
# cost:0.9567670471710887
# m:9.368692624386739
# b:2.2770510709693057
# iteration:35
# m_current*x+b_current:[11.6457437  21.01443632 30.38312894 39.75182157 49.12051419]
# cost:0.9503036042788691
# m:9.370957182763497
# b:2.269388492086715
# iteration:36
# m_current*x+b_current:[11.64034567 21.01130286 30.38226004 39.75321722 49.12417441]
# cost:0.9438857928372087
# m:9.373183293030324
# b:2.261743291279171
# iteration:37
# m_current*x+b_current:[11.63492658 21.00810988 30.38129317 39.75447646 49.12765976]
# cost:0.9375124703028581
# m:9.375378371086903
# b:2.254117427871768
# iteration:38
# m_current*x+b_current:[11.6294958  21.00487417 30.38025254 39.75563091 49.13100928]
# cost:0.931182850043531
# m:9.377548083775478
# b:2.2465123770491187
# iteration:39
# m_current*x+b_current:[11.62406046 21.00160854 30.37915663 39.75670471 49.1342528 ]
# cost:0.9248963536498084
# m:9.379696762721926
# b:2.2389292444816076
# iteration:40
# m_current*x+b_current:[11.61862601 20.99832277 30.37801953 39.7577163  49.13741306]
# cost:0.9186525248642727
# m:9.381827720254206
# b:2.23136885382866
# iteration:41
# m_current*x+b_current:[11.61319657 20.99502429 30.37685201 39.75867973 49.14050746]
# cost:0.9124509794182624
# m:9.38394349056856
# b:2.2238318135368345
# iteration:42
# m_current*x+b_current:[11.6077753  20.99171879 30.37566229 39.75960578 49.14354927]
# cost:0.9062913757937272
# m:9.386046013831267
# b:2.2163185678319843
# iteration:43
# m_current*x+b_current:[11.60236458 20.9884106  30.37445661 39.76050262 49.14654864]
# cost:0.9001733981793273
# m:9.388136776718468
# b:2.2088294356454687
# iteration:44
# m_current*x+b_current:[11.59696621 20.98510299 30.37323977 39.76137654 49.14951332]
# cost:0.894096746532717
# m:9.390216919701677
# b:2.201364640329451
# iteration:45
# m_current*x+b_current:[11.59158156 20.98179848 30.3720154  39.76223232 49.15244924]
# cost:0.8880611307840227
# m:9.392287318947542
# b:2.1939243323407616
# iteration:46
# m_current*x+b_current:[11.58621165 20.97849897 30.37078629 39.76307361 49.15536093]
# cost:0.8820662674526187
# m:9.394348648838637
# b:2.186508606557094
# iteration:47
# m_current*x+b_current:[11.58085726 20.9752059  30.36955455 39.7639032  49.15825185]
# cost:0.8761118776703196
# m:9.396401429700711
# b:2.179117515495634
# iteration:48
# m_current*x+b_current:[11.57551895 20.97192037 30.3683218  39.76472323 49.16112466]
# cost:0.8701976860241594
# m:9.398446064236817
# b:2.1717510794036787
# iteration:49
# m_current*x+b_current:[11.57019714 20.96864321 30.36708927 39.76553534 49.1639814 ]
# cost:0.8643234198768476
# m:9.400482865340496
# b:2.164409293961396
# iteration:50
# m_current*x+b_current:[11.56489216 20.96537502 30.36585789 39.76634076 49.16682362]
# cost:0.858488808965635
# m:9.402512077327904
# b:2.1570921361617383
# iteration:51
# m_current*x+b_current:[11.55960421 20.96211629 30.36462837 39.76714045 49.16965252]
# cost:0.8526935851634116
# m:9.40453389214606
# b:2.149799568798829
# iteration:52
# m_current*x+b_current:[11.55433346 20.95886735 30.36340125 39.76793514 49.17246903]
# cost:0.8469374823344475
# m:9.406548461745997
# b:2.142531543894089
# iteration:53
# m_current*x+b_current:[11.54908001 20.95562847 30.36217693 39.76872539 49.17527385]
# cost:0.841220236245249
# m:9.408555907528232
# b:2.1352880053114474
# iteration:54
# m_current*x+b_current:[11.54384391 20.95239982 30.36095573 39.76951164 49.17806754]
# cost:0.8355415845076287
# m:9.410556327553333
# b:2.1280688907535246
# iteration:55
# m_current*x+b_current:[11.53862522 20.94918155 30.35973787 39.7702942  49.18085053]
# cost:0.8299012665405434
# m:9.412549802046389
# b:2.120874133285254
# iteration:56
# m_current*x+b_current:[11.53342394 20.94597374 30.35852354 39.77107334 49.18362314]
# cost:0.8242990235429106
# m:9.414536397599068
# b:2.1137036624967656
# iteration:57
# m_current*x+b_current:[11.52824006 20.94277646 30.35731286 39.77184925 49.18638565]
# cost:0.8187345984728891
# m:9.416516170377468
# b:2.106557405390886
# iteration:58
# m_current*x+b_current:[11.52307358 20.93958975 30.35610592 39.77262209 49.18913826]
# cost:0.8132077360308823
# m:9.418489168570972
# b:2.0994352870604205
# iteration:59
# m_current*x+b_current:[11.51792446 20.93641362 30.35490279 39.77339196 49.19188113]
# cost:0.8077181826448435
# m:9.420455434261733
# b:2.092337231204954
# iteration:60
# m_current*x+b_current:[11.51279267 20.9332481  30.35370353 39.77415897 49.1946144 ]
# cost:0.8022656864568707
# m:9.422415004851855
# b:2.085263160525151
# iteration:61
# m_current*x+b_current:[11.50767817 20.93009317 30.35250818 39.77492318 49.19733818]
# cost:0.796849997310638
# m:9.424367914152938
# b:2.0782129970235363
# iteration:62
# m_current*x+b_current:[11.50258091 20.92694883 30.35131674 39.77568465 49.20005257]
# cost:0.7914708667393008
# m:9.42631419321788
# b:2.0711866622338895
# iteration:63
# m_current*x+b_current:[11.49750086 20.92381505 30.35012924 39.77644344 49.20275763]
# cost:0.7861280479537882
# m:9.428253870975913
# b:2.064184077396139
# iteration:64
# m_current*x+b_current:[11.49243795 20.92069182 30.34894569 39.77719956 49.20545343]
# cost:0.7808212958312398
# m:9.430186974717444
# b:2.057205163589661
# iteration:65
# m_current*x+b_current:[11.48739214 20.91757911 30.34776609 39.77795306 49.20814004]
# cost:0.7755503669036609
# m:9.432113530464227
# b:2.0502498418348214
# iteration:66
# m_current*x+b_current:[11.48236337 20.9144769  30.34659043 39.77870396 49.21081749]
# cost:0.7703150193466876
# m:9.434033563252008
# b:2.0433180331702716
# iteration:67
# m_current*x+b_current:[11.4773516  20.91138516 30.34541872 39.77945229 49.21348585]
# cost:0.7651150129684372
# m:9.43594709734635
# b:2.0364096587117455
# iteration:68
# m_current*x+b_current:[11.47235676 20.90830385 30.34425095 39.78019805 49.21614515]
# cost:0.7599501091984706
# m:9.437854156407449
# b:2.0295246396967297
# iteration:69
# m_current*x+b_current:[11.4673788  20.90523295 30.34308711 39.78094127 49.21879542]
# cost:0.7548200710768427
# m:9.439754763616007
# b:2.022662897518348
# iteration:70
# m_current*x+b_current:[11.46241766 20.90217242 30.34192719 39.78168195 49.22143672]
# cost:0.7497246632432119
# m:9.441648941769385
# b:2.0158243537510208
# iteration:71
# m_current*x+b_current:[11.4574733  20.89912224 30.34077118 39.78242012 49.22406906]
# cost:0.7446636519260408
# m:9.443536713355059
# b:2.0090089301698373
# iteration:72
# m_current*x+b_current:[11.45254564 20.89608236 30.33961907 39.78315578 49.2266925 ]
# cost:0.7396368049318749
# m:9.445418100606755
# b:2.002216548765137
# iteration:73
# m_current*x+b_current:[11.44763465 20.89305275 30.33847085 39.78388895 49.22930705]
# cost:0.7346438916346769
# m:9.447293125547361
# b:1.995447131753429
# iteration:74
# m_current*x+b_current:[11.44274026 20.89003338 30.33732651 39.78461963 49.23191276]
# cost:0.7296846829652446
# m:9.449161810021735
# b:1.9887006015855189
# iteration:75
# m_current*x+b_current:[11.43786241 20.88702422 30.33618603 39.78534784 49.23450965]
# cost:0.7247589514007186
# m:9.451024175721821
# b:1.9819768809525045
# iteration:76
# m_current*x+b_current:[11.43300106 20.88402523 30.33504941 39.78607358 49.23709776]
# cost:0.719866470954124
# m:9.45288024420587
# b:1.975275892790145
# iteration:77
# m_current*x+b_current:[11.42815614 20.88103638 30.33391663 39.78679687 49.23967711]
# cost:0.715007017164015
# m:9.45473003691317
# b:1.9685975602819898
# iteration:78
# m_current*x+b_current:[11.4233276  20.87805763 30.33278767 39.78751771 49.24224774]
# cost:0.7101803670841594
# m:9.456573575175353
# b:1.9619418068615597
# iteration:79
# m_current*x+b_current:[11.41851538 20.87508896 30.33166253 39.78823611 49.24480968]
# cost:0.7053862992733394
# m:9.458410880225081
# b:1.9553085562138073
# iteration:80
# m_current*x+b_current:[11.41371944 20.87213032 30.3305412  39.78895208 49.24736296]
# cost:0.7006245937851632
# m:9.460241973202734
# b:1.9486977322760262
# iteration:81
# m_current*x+b_current:[11.40893971 20.86918168 30.32942365 39.78966563 49.2499076 ]
# cost:0.6958950321579895
# m:9.462066875161572
# b:1.9421092592383415
# iteration:82
# m_current*x+b_current:[11.40417613 20.86624301 30.32830988 39.79037676 49.25244364]
# cost:0.6911973974048986
# m:9.463885607071726
# b:1.9355430615438804
# iteration:83
# m_current*x+b_current:[11.39942867 20.86331428 30.32719988 39.79108549 49.2549711 ]
# cost:0.6865314740037399
# m:9.465698189823312
# b:1.9289990638886994
# iteration:84
# m_current*x+b_current:[11.39469725 20.86039544 30.32609363 39.79179182 49.25749001]
# cost:0.681897047887246
# m:9.467504644228862
# b:1.9224771912215266
# iteration:85
# m_current*x+b_current:[11.38998184 20.85748648 30.32499112 39.79249577 49.26000041]
# cost:0.677293906433208
# m:9.46930499102522
# b:1.9159773687433643
# iteration:86
# m_current*x+b_current:[11.38528236 20.85458735 30.32389234 39.79319733 49.26250232]
# cost:0.672721838454722
# m:9.47109925087507
# b:1.909499521906984
# iteration:87
# m_current*x+b_current:[11.38059877 20.85169802 30.32279727 39.79389653 49.26499578]
# cost:0.668180634190496
# m:9.472887444368135
# b:1.90304357641634
# iteration:88
# m_current*x+b_current:[11.37593102 20.84881847 30.32170591 39.79459335 49.2674808 ]
# cost:0.6636700852952353
# m:9.474669592022165
# b:1.8966094582259252
# iteration:89
# m_current*x+b_current:[11.37127905 20.84594864 30.32061823 39.79528783 49.26995742]
# cost:0.6591899848300843
# m:9.476445714283733
# b:1.8901970935400767
# iteration:90
# m_current*x+b_current:[11.36664281 20.84308852 30.31953424 39.79597995 49.27242566]
# cost:0.6547401272531053
# m:9.478215831528907
# b:1.8838064088122513
# iteration:91
# m_current*x+b_current:[11.36202224 20.84023807 30.3184539  39.79666973 49.27488557]
# cost:0.6503203084098971
# m:9.479979964063812
# b:1.8774373307442718
# iteration:92
# m_current*x+b_current:[11.35741729 20.83739726 30.31737722 39.79735719 49.27733715]
# cost:0.6459303255241834
# m:9.481738132125116
# b:1.8710897862855576
# iteration:93
# m_current*x+b_current:[11.35282792 20.83456605 30.31630418 39.79804231 49.27978045]
# cost:0.6415699771885293
# m:9.483490355880457
# b:1.8647637026323394
# iteration:94
# m_current*x+b_current:[11.34825406 20.83174441 30.31523477 39.79872513 49.28221548]
# cost:0.6372390633551107
# m:9.485236655428816
# b:1.8584590072268652
# iteration:95
# m_current*x+b_current:[11.34369566 20.82893232 30.31416897 39.79940563 49.28464228]
# cost:0.6329373853265138
# m:9.486977050800865
# b:1.852175627756599
# iteration:96
# m_current*x+b_current:[11.33915268 20.82612973 30.31310678 39.80008383 49.28706088]
# cost:0.6286647457466337
# m:9.48871156195928
# b:1.845913492153415
# iteration:97
# m_current*x+b_current:[11.33462505 20.82333662 30.31204818 39.80075974 49.2894713 ]
# cost:0.6244209485916125
# m:9.490440208799033
# b:1.83967252859279
# iteration:98
# m_current*x+b_current:[11.33011274 20.82055295 30.31099315 39.80143336 49.29187357]
# cost:0.6202057991608646
# m:9.492163011147678
# b:1.8334526654929921
# iteration:99
# m_current*x+b_current:[11.32561568 20.81777869 30.3099417  39.80210471 49.29426772]
# cost:0.6160191040681107
# m:9.49387998876561
# b:1.8272538315142717
# iteration:100
# m_current*x+b_current:[11.32113382 20.81501381 30.3088938  39.80277379 49.29665378]
# cost:0.611860671232536
# m:9.495591161346319
# b:1.8210759555580496
# iteration:101
# m_current*x+b_current:[11.31666712 20.81225828 30.30784944 39.8034406  49.29903176]
# cost:0.6077303098699642
# m:9.497296548516646
# b:1.8149189667661094
# iteration:102
# m_current*x+b_current:[11.31221552 20.80951206 30.30680861 39.80410516 49.30140171]
# cost:0.6036278304841013
# m:9.498996169837017
# b:1.8087827945197885
# iteration:103
# m_current*x+b_current:[11.30777896 20.80677513 30.3057713  39.80476747 49.30376364]
# cost:0.5995530448578541
# m:9.500690044801686
# b:1.8026673684391716
# iteration:104
# m_current*x+b_current:[11.30335741 20.80404746 30.3047375  39.80542755 49.30611759]
# cost:0.5955057660446811
# m:9.502378192838965
# b:1.796572618382287
# iteration:105
# m_current*x+b_current:[11.29895081 20.801329   30.3037072  39.80608539 49.30846358]
# cost:0.5914858083600203
# m:9.504060633311456
# b:1.7904984744443033
# iteration:106
# m_current*x+b_current:[11.29455911 20.79861974 30.30268037 39.80674101 49.31080164]
# cost:0.5874929873727884
# m:9.505737385516277
# b:1.7844448669567299
# iteration:107
# m_current*x+b_current:[11.29018225 20.79591964 30.30165702 39.80739441 49.31313179]
# cost:0.5835271198968804
# m:9.507408468685291
# b:1.7784117264866186
# iteration:108
# m_current*x+b_current:[11.2858202  20.79322866 30.30063713 39.8080456  49.31545407]
# cost:0.5795880239828037
# m:9.50907390198533
# b:1.7723989838357688
# iteration:109
# m_current*x+b_current:[11.28147289 20.79054679 30.29962069 39.80869459 49.31776849]
# cost:0.5756755189093115
# m:9.510733704518412
# b:1.7664065700399336
# iteration:110
# m_current*x+b_current:[11.27714027 20.78787398 30.29860768 39.80934139 49.32007509]
# cost:0.5717894251751063
# m:9.512387895321964
# b:1.7604344163680303
# iteration:111
# m_current*x+b_current:[11.27282231 20.78521021 30.2975981  39.809986   49.32237389]
# cost:0.567929564490625
# m:9.514036493369051
# b:1.754482454321352
# iteration:112
# m_current*x+b_current:[11.26851895 20.78255544 30.29659193 39.81062843 49.32466492]
# cost:0.5640957597698407
# m:9.515679517568579
# b:1.748550615632782
# iteration:113
# m_current*x+b_current:[11.26423013 20.77990965 30.29558917 39.81126869 49.3269482 ]
# cost:0.5602878351221389
# m:9.517316986765525
# b:1.7426388322660116
# iteration:114
# m_current*x+b_current:[11.25995582 20.77727281 30.29458979 39.81190678 49.32922377]
# cost:0.5565056158442659
# m:9.518948919741149
# b:1.73674703641476
# iteration:115
# m_current*x+b_current:[11.25569596 20.77464488 30.2935938  39.81254272 49.33149164]
# cost:0.5527489284122935
# m:9.520575335213211
# b:1.7308751605019959
# iteration:116
# m_current*x+b_current:[11.2514505  20.77202583 30.29260117 39.8131765  49.33375184]
# cost:0.5490176004736631
# m:9.522196251836185
# b:1.7250231371791633
# iteration:117
# m_current*x+b_current:[11.24721939 20.76941564 30.29161189 39.81380814 49.3360044 ]
# cost:0.5453114608392922
# m:9.523811688201475
# b:1.719190899325409
# iteration:118
# m_current*x+b_current:[11.24300259 20.76681428 30.29062596 39.81443765 49.33824934]
# cost:0.5416303394756946
# m:9.525421662837626
# b:1.7133783800468123
# iteration:119
# m_current*x+b_current:[11.23880004 20.76422171 30.28964337 39.81506503 49.34048669]
# cost:0.5379740674972021
# m:9.52702619421054
# b:1.7075855126756185
# iteration:120
# m_current*x+b_current:[11.23461171 20.7616379  30.2886641  39.81569029 49.34271648]
# cost:0.5343424771582115
# m:9.528625300723684
# b:1.7018122307694736
# iteration:121
# m_current*x+b_current:[11.23043753 20.75906283 30.28768813 39.81631343 49.34493873]
# cost:0.5307354018454764
# m:9.530219000718304
# b:1.6960584681106632
# iteration:122
# m_current*x+b_current:[11.22627747 20.75649647 30.28671547 39.81693447 49.34715347]
# cost:0.5271526760704796
# m:9.531807312473637
# b:1.6903241587053517
# iteration:123
# m_current*x+b_current:[11.22213147 20.75393878 30.2857461  39.81755341 49.34936072]
# cost:0.523594135461828
# m:9.533390254207116
# b:1.6846092367828265
# iteration:124
# m_current*x+b_current:[11.21799949 20.75138975 30.28478    39.81817025 49.35156051]
# cost:0.5200596167577158
# m:9.53496784407458
# b:1.678913636794743
# iteration:125
# m_current*x+b_current:[11.21388148 20.74884932 30.28381717 39.81878501 49.35375286]
# cost:0.5165489577984402
# m:9.53654010017049
# b:1.6732372934143733
# iteration:126
# m_current*x+b_current:[11.20977739 20.74631749 30.28285759 39.81939769 49.35593779]
# cost:0.5130619975189538
# m:9.53810704052812
# b:1.6675801415358564
# iteration:127
# m_current*x+b_current:[11.20568718 20.74379422 30.28190126 39.8200083  49.35811534]
# cost:0.5095985759414761
# m:9.539668683119782
# b:1.661942116273452
# iteration:128
# m_current*x+b_current:[11.2016108  20.74127948 30.28094817 39.82061685 49.36028553]
# cost:0.5061585341681576
# m:9.541225045857022
# b:1.656323152960796
# iteration:129
# m_current*x+b_current:[11.1975482  20.73877324 30.27999829 39.82122334 49.36244838]
# cost:0.502741714373784
# m:9.54277614659083
# b:1.6507231871501589
# iteration:130
# m_current*x+b_current:[11.19349933 20.73627548 30.27905163 39.82182777 49.36460392]
# cost:0.4993479597985491
# m:9.544322003111837
# b:1.645142154611706
# iteration:131
# m_current*x+b_current:[11.18946416 20.73378616 30.27810816 39.82243017 49.36675217]
# cost:0.49597711474083844
# m:9.54586263315053
# b:1.6395799913327616
# iteration:132
# m_current*x+b_current:[11.18544262 20.73130526 30.27716789 39.82303052 49.36889316]
# cost:0.4926290245501096
# m:9.547398054377448
# b:1.6340366335170744
# iteration:133
# m_current*x+b_current:[11.18143469 20.72883274 30.2762308  39.82362885 49.37102691]
# cost:0.48930353561978657
# m:9.548928284403384
# b:1.628512017584086
# iteration:134
# m_current*x+b_current:[11.1774403  20.72636859 30.27529687 39.82422516 49.37315344]
# cost:0.48600049538021123
# m:9.550453340779594
# b:1.6230060801682011
# iteration:135
# m_current*x+b_current:[11.17345942 20.72391276 30.2743661  39.82481944 49.37527278]
# cost:0.4827197522916472
# m:9.551973240997992
# b:1.6175187581180615
# iteration:136
# m_current*x+b_current:[11.169492   20.72146524 30.27343848 39.82541172 49.37738496]
# cost:0.47946115583732696
# m:9.553488002491349
# b:1.6120499884958208
# iteration:137
# m_current*x+b_current:[11.16553799 20.71902599 30.272514   39.826002   49.37949   ]
# cost:0.47622455651654516
# m:9.554997642633504
# b:1.6065997085764234
# iteration:138
# m_current*x+b_current:[11.16159735 20.71659499 30.27159264 39.82659028 49.38158792]
# cost:0.4730098058377962
# m:9.556502178739548
# b:1.6011678558468847
# iteration:139
# m_current*x+b_current:[11.15767003 20.71417221 30.27067439 39.82717657 49.38367875]
# cost:0.46981675631196984
# m:9.558001628066034
# b:1.5957543680055741
# iteration:140
# m_current*x+b_current:[11.153756   20.71175762 30.26975925 39.82776088 49.38576251]
# cost:0.46664526144558
# m:9.559496007811171
# b:1.5903591829615007
# iteration:141
# m_current*x+b_current:[11.14985519 20.7093512  30.26884721 39.82834321 49.38783922]
# cost:0.46349517573404
# m:9.560985335115024
# b:1.5849822388336003
# iteration:142
# m_current*x+b_current:[11.14596757 20.70695291 30.26793824 39.82892358 49.38990891]
# cost:0.46036635465499565
# m:9.562469627059702
# b:1.5796234739500268
# iteration:143
# m_current*x+b_current:[11.1420931  20.70456273 30.26703236 39.82950198 49.39197161]
# cost:0.4572586546616851
# m:9.563948900669565
# b:1.574282826847444
# iteration:144
# m_current*x+b_current:[11.13823173 20.70218063 30.26612953 39.83007843 49.39402733]
# cost:0.4541719331763638
# m:9.565423172911414
# b:1.5689602362703212
# iteration:145
# m_current*x+b_current:[11.13438341 20.69980658 30.26522976 39.83065293 49.3960761 ]
# cost:0.4511060485837523
# m:9.566892460694683
# b:1.56365564117023
# iteration:146
# m_current*x+b_current:[11.1305481  20.69744056 30.26433302 39.83122548 49.39811794]
# cost:0.44806086022454555
# m:9.568356780871639
# b:1.5583689807051444
# iteration:147
# m_current*x+b_current:[11.12672576 20.69508254 30.26343932 39.8317961  49.40015289]
# cost:0.44503622838896134
# m:9.56981615023757
# b:1.5531001942387432
# iteration:148
# m_current*x+b_current:[11.12291634 20.69273249 30.26254864 39.8323648  49.40218095]
# cost:0.44203201431031885
# m:9.571270585530979
# b:1.5478492213397141
# iteration:149
# m_current*x+b_current:[11.11911981 20.69039039 30.26166098 39.83293156 49.40420215]
# cost:0.4390480801586937
# m:9.572720103433781
# b:1.542616001781061
# iteration:150
# m_current*x+b_current:[11.11533611 20.68805621 30.26077631 39.83349642 49.40621652]
# cost:0.43608428903456853
# m:9.574164720571485
# b:1.537400475539413
# iteration:151
# m_current*x+b_current:[11.1115652  20.68572992 30.25989464 39.83405936 49.40822408]
# cost:0.4331405049625759
# m:9.575604453513392
# b:1.5322025827943357
# iteration:152
# m_current*x+b_current:[11.10780704 20.68341149 30.25901594 39.8346204  49.41022485]
# cost:0.4302165928852422
# m:9.577039318772785
# b:1.5270222639276454
# iteration:153
# m_current*x+b_current:[11.10406158 20.6811009  30.25814022 39.83517954 49.41221886]
# cost:0.4273124186568012
# m:9.578469332807114
# b:1.5218594595227253
# iteration:154
# m_current*x+b_current:[11.10032879 20.67879813 30.25726746 39.83573679 49.41420612]
# cost:0.42442784903703235
# m:9.579894512018186
# b:1.516714110363844
# iteration:155
# m_current*x+b_current:[11.09660862 20.67650313 30.25639765 39.83629216 49.41618667]
# cost:0.4215627516851619
# m:9.581314872752355
# b:1.5115861574354759
# iteration:156
# m_current*x+b_current:[11.09290103 20.6742159  30.25553078 39.83684565 49.41816052]
# cost:0.41871699515377225
# m:9.582730431300709
# b:1.5064755419216251
# iteration:157
# m_current*x+b_current:[11.08920597 20.6719364  30.25466684 39.83739727 49.4201277 ]
# cost:0.41589044888278526
# m:9.584141203899256
# b:1.5013822052051502
# iteration:158
# m_current*x+b_current:[11.08552341 20.66966461 30.25380582 39.83794702 49.42208822]
# cost:0.4130829831934663
# m:9.58554720672911
# b:1.4963060888670918
# iteration:159
# m_current*x+b_current:[11.0818533  20.6674005  30.25294771 39.83849492 49.42404212]
# cost:0.4102944692824781
# m:9.58694845591668
# b:1.4912471346860035
# iteration:160
# m_current*x+b_current:[11.07819559 20.66514405 30.2520925  39.83904096 49.42598941]
# cost:0.4075247792159655
# m:9.58834496753385
# b:1.4862052846372826
# iteration:161
# m_current*x+b_current:[11.07455025 20.66289522 30.25124019 39.83958515 49.42793012]
# cost:0.4047737859236946
# m:9.589736757598166
# b:1.481180480892506
# iteration:162
# m_current*x+b_current:[11.07091724 20.660654   30.25039075 39.84012751 49.42986427]
# cost:0.40204136319321715
# m:9.591123842073019
# b:1.476172665818766
# iteration:163
# m_current*x+b_current:[11.06729651 20.65842035 30.24954419 39.84066803 49.43179188]
# cost:0.3993273856640775
# m:9.592506236867829
# b:1.4711817819780095
# iteration:164
# m_current*x+b_current:[11.06368802 20.65619426 30.24870049 39.84120673 49.43371297]
# cost:0.3966317288220693
# m:9.593883957838226
# b:1.4662077721263795
# iteration:165
# m_current*x+b_current:[11.06009173 20.65397569 30.24785965 39.8417436  49.43562756]
# cost:0.3939542689935153
# m:9.595257020786233
# b:1.4612505792135584
# iteration:166
# m_current*x+b_current:[11.0565076  20.65176462 30.24702164 39.84227866 49.43753568]
# cost:0.39129488333959717
# m:9.596625441460448
# b:1.4563101463821133
# iteration:167
# m_current*x+b_current:[11.05293559 20.64956103 30.24618647 39.84281191 49.43943735]
# cost:0.388653449850725
# m:9.597989235556224
# b:1.4513864169668442
# iteration:168
# m_current*x+b_current:[11.04937565 20.64736489 30.24535412 39.84334336 49.44133259]
# cost:0.3860298473409232
# m:9.599348418715843
# b:1.446479334494134
# iteration:169
# m_current*x+b_current:[11.04582775 20.64517617 30.24452459 39.84387301 49.44322143]
# cost:0.3834239554422909
# m:9.60070300652871
# b:1.4415888426813006
# iteration:170
# m_current*x+b_current:[11.04229185 20.64299486 30.24369786 39.84440087 49.44510388]
# cost:0.38083565459946433
# m:9.602053014531515
# b:1.436714885435952
# iteration:171
# m_current*x+b_current:[11.0387679  20.64082091 30.24287393 39.84492694 49.44697996]
# cost:0.37826482606413886
# m:9.603398458208424
# b:1.431857406855342
# iteration:172
# m_current*x+b_current:[11.03525587 20.63865432 30.24205278 39.84545124 49.4488497 ]
# cost:0.37571135188961974
# m:9.60473935299125
# b:1.4270163512257297
# iteration:173
# m_current*x+b_current:[11.0317557  20.63649506 30.24123441 39.84597376 49.45071312]
# cost:0.3731751149254121
# m:9.606075714259632
# b:1.42219166302174
# iteration:174
# m_current*x+b_current:[11.02826738 20.63434309 30.24041881 39.84649452 49.45257023]
# cost:0.37065599881184147
# m:9.607407557341208
# b:1.4173832869057272
# iteration:175
# m_current*x+b_current:[11.02479084 20.6321984  30.23960596 39.84701352 49.45442107]
# cost:0.36815388797472126
# m:9.608734897511798
# b:1.4125911677271403
# iteration:176
# m_current*x+b_current:[11.02132607 20.63006096 30.23879586 39.84753076 49.45626566]
# cost:0.36566866762004946
# m:9.610057749995574
# b:1.4078152505218897
# iteration:177
# m_current*x+b_current:[11.017873   20.62793075 30.2379885  39.84804625 49.458104  ]
# cost:0.36320022372872973
# m:9.611376129965235
# b:1.4030554805117175
# iteration:178
# m_current*x+b_current:[11.01443161 20.62580774 30.23718387 39.84856    49.45993613]
# cost:0.3607484430513648
# m:9.612690052542181
# b:1.398311803103569
# iteration:179
# m_current*x+b_current:[11.01100186 20.62369191 30.23638196 39.84907201 49.46176207]
# cost:0.3583132131030404
# m:9.613999532796687
# b:1.3935841638889668
# iteration:180
# m_current*x+b_current:[11.0075837  20.62158323 30.23558276 39.8495823  49.46358183]
# cost:0.3558944221581703
# m:9.615304585748078
# b:1.3888725086433862
# iteration:181
# m_current*x+b_current:[11.00417709 20.61948168 30.23478627 39.85009085 49.46539544]
# cost:0.35349195924536975
# m:9.616605226364896
# b:1.3841767833256338
# iteration:182
# m_current*x+b_current:[11.00078201 20.61738724 30.23399246 39.85059769 49.46720292]
# cost:0.35110571414236824
# m:9.617901469565082
# b:1.3794969340772272
# iteration:183
# m_current*x+b_current:[10.9973984  20.61529987 30.23320134 39.85110281 49.46900428]
# cost:0.34873557737095107
# m:9.619193330216131
# b:1.3748329072217778
# iteration:184
# m_current*x+b_current:[10.99402624 20.61321957 30.2324129  39.85160623 49.47079956]
# cost:0.3463814401919331
# m:9.620480823135276
# b:1.3701846492643743
# iteration:185
# m_current*x+b_current:[10.99066547 20.6111463  30.23162712 39.85210794 49.47258876]
# cost:0.3440431946001701
# m:9.621763963089652
# b:1.3655521068909704
# iteration:186
# m_current*x+b_current:[10.98731607 20.60908003 30.230844   39.85260796 49.47437192]
# cost:0.34172073331961567
# m:9.62304276479647
# b:1.360935226967772
# iteration:187
# m_current*x+b_current:[10.98397799 20.60702076 30.23006352 39.85310629 49.47614905]
# cost:0.33941394979837597
# m:9.62431724292318
# b:1.3563339565406283
# iteration:188
# m_current*x+b_current:[10.9806512  20.60496844 30.22928569 39.85360293 49.47792017]
# cost:0.33712273820384725
# m:9.625587412087642
# b:1.351748242834425
# iteration:189
# m_current*x+b_current:[10.97733565 20.60292307 30.22851048 39.85409789 49.4796853 ]
# cost:0.33484699341783336
# m:9.626853286858296
# b:1.3471780332524779
# iteration:190
# m_current*x+b_current:[10.97403132 20.60088461 30.22773789 39.85459118 49.48144447]
# cost:0.33258661103175996
# m:9.628114881754323
# b:1.3426232753759306
# iteration:191
# m_current*x+b_current:[10.97073816 20.59885304 30.22696792 39.8550828  49.48319768]
# cost:0.3303414873418406
# m:9.629372211245816
# b:1.3380839169631527
# iteration:192
# m_current*x+b_current:[10.96745613 20.59682834 30.22620055 39.85557276 49.48494497]
# cost:0.3281115193443494
# m:9.630625289753947
# b:1.3335599059491408
# iteration:193
# m_current*x+b_current:[10.9641852  20.59481049 30.22543578 39.85606106 49.48668635]
# cost:0.3258966047308885
# m:9.63187413165113
# b:1.3290511904449211
# iteration:194
# m_current*x+b_current:[10.96092532 20.59279945 30.22467359 39.85654772 49.48842185]
# cost:0.3236966418836858
# m:9.633118751261186
# b:1.3245577187369548
# iteration:195
# m_current*x+b_current:[10.95767647 20.59079522 30.22391397 39.85703272 49.49015148]
# cost:0.3215115298709516
# m:9.634359162859507
# b:1.3200794392865445
# iteration:196
# m_current*x+b_current:[10.9544386  20.58879777 30.22315693 39.85751609 49.49187525]
# cost:0.31934116844222
# m:9.635595380673223
# b:1.3156163007292432
# iteration:197
# m_current*x+b_current:[10.95121168 20.58680706 30.22240244 39.85799782 49.4935932 ]
# cost:0.31718545802377446
# m:9.63682741888136
# b:1.311168251874265
# iteration:198
# m_current*x+b_current:[10.94799567 20.58482309 30.22165051 39.85847793 49.49530535]
# cost:0.31504429971406855
# m:9.638055291615006
# b:1.306735241703898
# iteration:199
# m_current*x+b_current:[10.94479053 20.58284582 30.22090112 39.85895641 49.4970117 ]
# cost:0.3129175952791907
# m:9.63927901295747
# b:1.3023172193729198
# iteration:200
# m_current*x+b_current:[10.94159623 20.58087525 30.22015426 39.85943327 49.49871228]
# cost:0.3108052471483549
# m:9.640498596944452
# b:1.2979141342080132
# iteration:201
# m_current*x+b_current:[10.93841273 20.57891133 30.21940993 39.85990852 49.50040712]
# cost:0.308707158409426
# m:9.641714057564192
# b:1.2935259357071858
# iteration:202
# m_current*x+b_current:[10.93523999 20.57695405 30.21866811 39.86038217 49.50209622]
# cost:0.3066232328044737
# m:9.64292540875764
# b:1.2891525735391904
# iteration:203
# m_current*x+b_current:[10.93207798 20.57500339 30.2179288  39.86085421 49.50377962]
# cost:0.3045533747253597
# m:9.644132664418606
# b:1.2847939975429483
# iteration:204
# m_current*x+b_current:[10.92892666 20.57305933 30.21719199 39.86132466 49.50545732]
# cost:0.3024974892093436
# m:9.645335838393937
# b:1.280450157726973
# iteration:205
# m_current*x+b_current:[10.925786   20.57112183 30.21645767 39.86179351 49.50712935]
# cost:0.30045548193473237
# m:9.646534944483653
# b:1.2761210042687972
# iteration:206
# m_current*x+b_current:[10.92265595 20.56919089 30.21572584 39.86226078 49.50879573]
# cost:0.29842725921654983
# m:9.647729996441122
# b:1.271806487514402
# iteration:207
# m_current*x+b_current:[10.91953648 20.56726648 30.21499648 39.86272647 49.51045647]
# cost:0.29641272800223945
# m:9.648921007973211
# b:1.2675065579776466
# iteration:208
# m_current*x+b_current:[10.91642757 20.56534857 30.21426958 39.86319059 49.5121116 ]
# cost:0.2944117958673969
# m:9.650107992740447
# b:1.2632211663397008
# iteration:209
# m_current*x+b_current:[10.91332916 20.56343715 30.21354514 39.86365314 49.51376113]
# cost:0.29242437101152696
# m:9.651290964357166
# b:1.2589502634484802
# iteration:210
# m_current*x+b_current:[10.91024123 20.56153219 30.21282316 39.86411412 49.51540509]
# cost:0.2904503622538359
# m:9.65246993639168
# b:1.2546938003180805
# iteration:211
# m_current*x+b_current:[10.90716374 20.55963367 30.21210361 39.86457355 49.51704348]
# cost:0.28848967902903655
# m:9.653644922366427
# b:1.2504517281282181
# iteration:212
# m_current*x+b_current:[10.90409665 20.55774157 30.2113865  39.86503142 49.51867634]
# cost:0.2865422313832152
# m:9.65481593575812
# b:1.2462239982236683
# iteration:213
# m_current*x+b_current:[10.90103993 20.55585587 30.21067181 39.86548774 49.52030368]
# cost:0.2846079299696826
# m:9.655982989997913
# b:1.2420105621137076
# iteration:214
# m_current*x+b_current:[10.89799355 20.55397654 30.20995953 39.86594252 49.52192551]
# cost:0.28268668604488306
# m:9.65714609847155
# b:1.2378113714715588
# iteration:215
# m_current*x+b_current:[10.89495747 20.55210357 30.20924967 39.86639577 49.52354186]
# cost:0.28077841146433147
# m:9.658305274519515
# b:1.2336263781338346
# iteration:216
# m_current*x+b_current:[10.89193165 20.55023693 30.2085422  39.86684748 49.52515275]
# cost:0.27888301867854925
# m:9.659460531437192
# b:1.229455534099987
# iteration:217
# m_current*x+b_current:[10.88891607 20.5483766  30.20783713 39.86729766 49.52675819]
# cost:0.27700042072907366
# m:9.66061188247501
# b:1.2252987915317557
# iteration:218
# m_current*x+b_current:[10.88591067 20.54652256 30.20713444 39.86774632 49.5283582 ]
# cost:0.27513053124444353
# m:9.661759340838602
# b:1.2211561027526199
# iteration:219
# m_current*x+b_current:[10.88291544 20.54467478 30.20643413 39.86819347 49.52995281]
# cost:0.27327326443625544
# m:9.662902919688952
# b:1.2170274202472513
# iteration:220
# m_current*x+b_current:[10.87993034 20.54283326 30.20573618 39.8686391  49.53154202]
# cost:0.27142853509521364
# m:9.664042632142547
# b:1.2129126966609691
# iteration:221
# m_current*x+b_current:[10.87695533 20.54099796 30.20504059 39.86908323 49.53312586]
# cost:0.2695962585872335
# m:9.665178491271528
# b:1.2088118847991969
# iteration:222
# m_current*x+b_current:[10.87399038 20.53916887 30.20434736 39.86952585 49.53470434]
# cost:0.2677763508495438
# m:9.66631051010384
# b:1.2047249376269213
# iteration:223
# m_current*x+b_current:[10.87103545 20.53734596 30.20365647 39.86996698 49.53627749]
# cost:0.26596872838685004
# m:9.667438701623379
# b:1.2006518082681525
# iteration:224
# m_current*x+b_current:[10.86809051 20.53552921 30.20296791 39.87040661 49.53784532]
# cost:0.26417330826747965
# m:9.668563078770147
# b:1.1965924500053868
# iteration:225
# m_current*x+b_current:[10.86515553 20.53371861 30.20228169 39.87084477 49.53940784]
# cost:0.26239000811959834
# m:9.66968365444039
# b:1.1925468162790702
# iteration:226
# m_current*x+b_current:[10.86223047 20.53191413 30.20159778 39.87128143 49.54096509]
# cost:0.2606187461274212
# m:9.67080044148676
# b:1.1885148606870655
# iteration:227
# m_current*x+b_current:[10.8593153  20.53011574 30.20091619 39.87171663 49.54251707]
# cost:0.25885944102745795
# m:9.67191345271845
# b:1.1844965369841185
# iteration:228
# m_current*x+b_current:[10.85640999 20.52832344 30.2002369  39.87215035 49.5440638 ]
# cost:0.2571120121047864
# m:9.673022700901344
# b:1.180491799081329
# iteration:229
# m_current*x+b_current:[10.8535145 20.5265372 30.1995599 39.8725826 49.5456053]
# cost:0.2553763791893512
# m:9.674128198758169
# b:1.1765006010456218
# iteration:230
# m_current*x+b_current:[10.8506288  20.524757   30.1988852  39.8730134  49.54714159]
# cost:0.25365246265228675
# m:9.675229958968634
# b:1.1725228970992192
# iteration:231
# m_current*x+b_current:[10.84775286 20.52298282 30.19821277 39.87344273 49.54867269]
# cost:0.2519401834022564
# m:9.676327994169581
# b:1.1685586416191167
# iteration:232
# m_current*x+b_current:[10.84488664 20.52121463 30.19754262 39.87387062 49.55019861]
# cost:0.250239462881835
# m:9.677422316955127
# b:1.1646077891365596
# iteration:233
# m_current*x+b_current:[10.84203011 20.51945242 30.19687474 39.87429706 49.55171937]
# cost:0.24855022306389465
# m:9.678512939876805
# b:1.1606702943365208
# iteration:234
# m_current*x+b_current:[10.83918323 20.51769617 30.19620911 39.87472205 49.55323499]
# cost:0.246872386448028
# m:9.679599875443717
# b:1.156746112057182
# iteration:235
# m_current*x+b_current:[10.83634599 20.51594586 30.19554574 39.87514561 49.55474549]
# cost:0.24520587605700006
# m:9.680683136122669
# b:1.1528351972894153
# iteration:236
# m_current*x+b_current:[10.83351833 20.51420147 30.19488461 39.87556774 49.55625088]
# cost:0.24355061543320128
# m:9.681762734338317
# b:1.148937505176267
# iteration:237
# m_current*x+b_current:[10.83070024 20.51246297 30.19422571 39.87598844 49.55775118]
# cost:0.24190652863515802
# m:9.682838682473312
# b:1.1450529910124425
# iteration:238
# m_current*x+b_current:[10.82789167 20.51073036 30.19356904 39.87640772 49.5592464 ]
# cost:0.2402735402340296
# m:9.683910992868437
# b:1.141181610243795
# iteration:239
# m_current*x+b_current:[10.8250926  20.5090036  30.19291459 39.87682558 49.56073657]
# cost:0.2386515753101656
# m:9.684979677822753
# b:1.137323318466813
# iteration:240
# m_current*x+b_current:[10.822303   20.50728267 30.19226235 39.87724203 49.56222171]
# cost:0.23704055944965383
# m:9.686044749593739
# b:1.1334780714281116
# iteration:241
# m_current*x+b_current:[10.81952282 20.50556757 30.19161232 39.87765707 49.56370182]
# cost:0.23544041874091826
# m:9.68710622039743
# b:1.129645825023925
# iteration:242
# m_current*x+b_current:[10.81675205 20.50385827 30.19096449 39.87807071 49.56517693]
# cost:0.2338510797713175
# m:9.68816410240856
# b:1.1258265352996006
# iteration:243
# m_current*x+b_current:[10.81399064 20.50215474 30.19031884 39.87848294 49.56664705]
# cost:0.23227246962378492
# m:9.6892184077607
# b:1.122020158449095
# iteration:244
# m_current*x+b_current:[10.81123857 20.50045697 30.18967538 39.87889379 49.5681122 ]
# cost:0.23070451587347995
# m:9.6902691485464
# b:1.1182266508144711
# iteration:245
# m_current*x+b_current:[10.8084958  20.49876495 30.1890341  39.87930325 49.56957239]
# cost:0.22914714658446403
# m:9.691316336817325
# b:1.1144459688853976
# iteration:246
# m_current*x+b_current:[10.80576231 20.49707864 30.18839498 39.87971132 49.57102765]
# cost:0.22760029030640017
# m:9.692359984584389
# b:1.1106780692986502
# iteration:247
# m_current*x+b_current:[10.80303805 20.49539804 30.18775802 39.88011801 49.57247799]
# cost:0.22606387607127956
# m:9.693400103817904
# b:1.1069229088376138
# iteration:248
# m_current*x+b_current:[10.80032301 20.49372312 30.18712322 39.88052332 49.57392343]
# cost:0.2245378333901622
# m:9.694436706447709
# b:1.1031804444317872
# iteration:249
# m_current*x+b_current:[10.79761715 20.49205386 30.18649056 39.88092727 49.57536398]
# cost:0.22302209224994038
# m:9.695469804363306
# b:1.099450633156289
# iteration:250
# m_current*x+b_current:[10.79492044 20.49039024 30.18586005 39.88132985 49.57679965]
# cost:0.22151658311013206
# m:9.696499409414
# b:1.095733432231365
# iteration:251
# m_current*x+b_current:[10.79223284 20.48873225 30.18523166 39.88173107 49.57823048]
# cost:0.22002123689968844
# m:9.697525533409038
# b:1.0920287990218978
# iteration:252
# m_current*x+b_current:[10.78955433 20.48707987 30.1846054  39.88213093 49.57965647]
# cost:0.21853598501382177
# m:9.698548188117737
# b:1.0883366910369174
# iteration:253
# m_current*x+b_current:[10.78688488 20.48543307 30.18398126 39.88252944 49.58107763]
# cost:0.2170607593108617
# m:9.69956738526962
# b:1.0846570659291148
# iteration:254
# m_current*x+b_current:[10.78422445 20.48379184 30.18335922 39.88292661 49.58249399]
# cost:0.21559549210912674
# m:9.700583136554558
# b:1.0809898814943553
# iteration:255
# m_current*x+b_current:[10.78157302 20.48215615 30.18273929 39.88332243 49.58390556]
# cost:0.21414011618382212
# m:9.701595453622893
# b:1.0773350956711947
# iteration:256
# m_current*x+b_current:[10.77893055 20.480526   30.18212146 39.88371691 49.58531236]
# cost:0.21269456476395235
# m:9.702604348085584
# b:1.0736926665403972
# iteration:257
# m_current*x+b_current:[10.77629701 20.47890136 30.18150571 39.88411006 49.58671441]
# cost:0.21125877152925923
# m:9.703609831514331
# b:1.0700625523244542
# iteration:258
# m_current*x+b_current:[10.77367238 20.47728222 30.18089205 39.88450188 49.58811171]
# cost:0.2098326706071789
# m:9.704611915441712
# b:1.0664447113871054
# iteration:259
# m_current*x+b_current:[10.77105663 20.47566854 30.18028046 39.88489237 49.58950429]
# cost:0.2084161965698227
# m:9.705610611361308
# b:1.0628391022328605
# iteration:260
# m_current*x+b_current:[10.76844971 20.47406032 30.17967094 39.88528155 49.59089216]
# cost:0.2070092844309641
# m:9.706605930727848
# b:1.0592456835065247
# iteration:261
# m_current*x+b_current:[10.76585161 20.47245754 30.17906348 39.88566941 49.59227534]
# cost:0.20561186964307648
# m:9.70759788495733
# b:1.0556644139927234
# iteration:262
# m_current*x+b_current:[10.7632623  20.47086018 30.17845807 39.88605595 49.59365384]
# cost:0.20422388809435296
# m:9.708586485427155
# b:1.052095252615429
# iteration:263
# m_current*x+b_current:[10.76068174 20.46926822 30.17785471 39.88644119 49.59502768]
# cost:0.20284527610577624
# m:9.709571743476255
# b:1.048538158437491
# iteration:264
# m_current*x+b_current:[10.7581099  20.46768165 30.17725339 39.88682513 49.59639688]
# cost:0.20147597042819432
# m:9.710553670405229
# b:1.0449930906601659
# iteration:265
# m_current*x+b_current:[10.75554676 20.46610043 30.1766541  39.88720777 49.59776144]
# cost:0.20011590823941786
# m:9.711532277476469
# b:1.0414600086226489
# iteration:266
# m_current*x+b_current:[10.75299229 20.46452456 30.17605684 39.88758912 49.5991214 ]
# cost:0.19876502714133393
# m:9.712507575914287
# b:1.0379388718016078
# iteration:267
# m_current*x+b_current:[10.75044645 20.46295402 30.1754616  39.88796918 49.60047675]
# cost:0.1974232651570551
# m:9.713479576905048
# b:1.0344296398107184
# iteration:268
# m_current*x+b_current:[10.74790922 20.46138879 30.17486837 39.88834795 49.60182752]
# cost:0.19609056072806227
# m:9.714448291597295
# b:1.0309322724002012
# iteration:269
# m_current*x+b_current:[10.74538056 20.45982886 30.17427715 39.88872544 49.60317373]
# cost:0.19476685271139121
# m:9.715413731101878
# b:1.0274467294563596
# iteration:270
# m_current*x+b_current:[10.74286046 20.45827419 30.17368792 39.88910165 49.60451538]
# cost:0.1934520803768196
# m:9.716375906492082
# b:1.0239729710011198
# iteration:271
# m_current*x+b_current:[10.74034888 20.45672478 30.17310069 39.8894766  49.6058525 ]
# cost:0.19214618340408568
# m:9.717334828803757
# b:1.0205109571915725
# iteration:272
# m_current*x+b_current:[10.73784579 20.45518061 30.17251544 39.88985027 49.6071851 ]
# cost:0.1908491018801165
# m:9.718290509035436
# b:1.0170606483195155
# iteration:273
# m_current*x+b_current:[10.73535116 20.45364167 30.17193218 39.89022268 49.60851319]
# cost:0.18956077629628773
# m:9.719242958148469
# b:1.013622004810999
# iteration:274
# m_current*x+b_current:[10.73286496 20.45210792 30.17135088 39.89059384 49.6098368 ]
# cost:0.18828114754568423
# m:9.720192187067145
# b:1.0101949872258709
# iteration:275
# m_current*x+b_current:[10.73038717 20.45057936 30.17077155 39.89096374 49.61115592]
# cost:0.18701015692038778
# m:9.721138206678821
# b:1.0067795562573247
# iteration:276
# m_current*x+b_current:[10.72791776 20.44905597 30.17019418 39.89133238 49.61247059]
# cost:0.1857477461087947
# m:9.722081027834042
# b:1.003375672731449
# iteration:277
# m_current*x+b_current:[10.7254567  20.44753773 30.16961876 39.89169978 49.61378081]
# cost:0.18449385719292757
# m:9.723020661346666
# b:0.9999832976067774
# iteration:278
# m_current*x+b_current:[10.72300396 20.44602462 30.16904528 39.89206594 49.6150866 ]
# cost:0.18324843264578897
# m:9.723957117993994
# b:0.9966023919738419
# iteration:279
# m_current*x+b_current:[10.72055951 20.44451663 30.16847375 39.89243086 49.61638798]
# cost:0.18201141532871476
# m:9.724890408516885
# b:0.9932329170547255
# iteration:280
# m_current*x+b_current:[10.71812333 20.44301373 30.16790414 39.89279455 49.61768496]
# cost:0.18078274848875064
# m:9.725820543619886
# b:0.9898748342026179
# iteration:281
# m_current*x+b_current:[10.71569538 20.44151592 30.16733647 39.89315701 49.61897755]
# cost:0.1795623757560611
# m:9.726747533971354
# b:0.9865281049013724
# iteration:282
# m_current*x+b_current:[10.71327564 20.44002317 30.16677071 39.89351824 49.62026577]
# cost:0.17835024114132755
# m:9.727671390203573
# b:0.9831926907650638
# iteration:283
# m_current*x+b_current:[10.71086408 20.43853547 30.16620686 39.89387825 49.62154964]
# cost:0.17714628903319124
# m:9.728592122912882
# b:0.9798685535375481
# iteration:284
# m_current*x+b_current:[10.70846068 20.4370528  30.16564492 39.89423705 49.62282917]
# cost:0.1759504641956975
# m:9.729509742659795
# b:0.9765556550920241
# iteration:285
# m_current*x+b_current:[10.7060654  20.43557514 30.16508488 39.89459463 49.62410437]
# cost:0.17476271176575817
# m:9.73042425996912
# b:0.973253957430596
# iteration:286
# m_current*x+b_current:[10.70367822 20.43410248 30.16452674 39.894951   49.62537526]
# cost:0.17358297725064264
# m:9.731335685330077
# b:0.9699634226838368
# iteration:287
# m_current*x+b_current:[10.70129911 20.43263479 30.16397048 39.89530616 49.62664185]
# cost:0.17241120652546693
# m:9.73224402919643
# b:0.9666840131103555
# iteration:288
# m_current*x+b_current:[10.69892804 20.43117207 30.1634161  39.89566013 49.62790416]
# cost:0.17124734583072038
# m:9.733149301986595
# b:0.9634156910963626
# iteration:289
# m_current*x+b_current:[10.69656499 20.4297143  30.1628636  39.8960129  49.6291622 ]
# cost:0.1700913417698021
# m:9.734051514083761
# b:0.9601584191552397
# iteration:290
# m_current*x+b_current:[10.69420993 20.42826145 30.16231296 39.89636448 49.63041599]
# cost:0.16894314130654964
# m:9.73495067583602
# b:0.9569121599271092
# iteration:291
# m_current*x+b_current:[10.69186284 20.42681351 30.16176419 39.89671486 49.63166554]
# cost:0.16780269176283502
# m:9.73584679755647
# b:0.9536768761784059
# iteration:292
# m_current*x+b_current:[10.68952367 20.42537047 30.16121727 39.89706407 49.63291086]
# cost:0.1666699408161267
# m:9.736739889523342
# b:0.9504525308014496
# iteration:293
# m_current*x+b_current:[10.68719242 20.42393231 30.1606722  39.89741209 49.63415198]
# cost:0.16554483649709414
# m:9.73762996198012
# b:0.9472390868140201
# iteration:294
# m_current*x+b_current:[10.68486905 20.42249901 30.16012897 39.89775893 49.6353889 ]
# cost:0.16442732718723146
# m:9.738517025135653
# b:0.9440365073589325
# iteration:295
# m_current*x+b_current:[10.68255353 20.42107056 30.15958758 39.89810461 49.63662163]
# cost:0.16331736161647933
# m:9.739401089164273
# b:0.9408447557036147
# iteration:296
# m_current*x+b_current:[10.68024584 20.41964693 30.15904802 39.89844911 49.6378502 ]
# cost:0.1622148888608789
# ...
# cost:0.00265774946597601
# m:9.966755987388758
# b:0.12002143379465845
# iteration:904
# m_current*x+b_current:[10.08677742 20.05353341 30.0202894  39.98704538 49.95380137]
# cost:0.0026398083460089992
# m:9.966868384135552
# b:0.11961564587543976
# iteration:905
# m_current*x+b_current:[10.08648403 20.05335241 30.0202208  39.98708918 49.95395757]
# cost:0.002621988337452245
# m:9.966980400873204
# b:0.11921122990979786
# iteration:906
# m_current*x+b_current:[10.08619163 20.05317203 30.02015243 39.98713283 49.95411323]
# cost:0.002604288622743804
# m:9.967092038886511
# b:0.11880818125920961
# iteration:907
# m_current*x+b_current:[10.08590022 20.05299226 30.0200843  39.98717634 49.95426838]
# cost:0.0025867083898409426
# m:9.967203299455926
# b:0.11840649530083476
# iteration:908
# m_current*x+b_current:[10.08560979 20.05281309 30.02001639 39.98721969 49.95442299]
# cost:0.0025692468321824886
# m:9.967314183857573
# b:0.1180061674274625
# iteration:909
# m_current*x+b_current:[10.08532035 20.05263454 30.01994872 39.9872629  49.95457709]
# cost:0.002551903148652354
# m:9.96742469336326
# b:0.11760719304745891
# iteration:910
# m_current*x+b_current:[10.08503189 20.05245658 30.01988127 39.98730597 49.95473066]
# cost:0.002534676543541356
# m:9.967534829240495
# b:0.11720956758471415
# iteration:911
# m_current*x+b_current:[10.0847444  20.05227923 30.01981406 39.98734888 49.95488371]
# cost:0.002517566226512742
# m:9.967644592752503
# b:0.11681328647859016
# iteration:912
# m_current*x+b_current:[10.08445788 20.05210247 30.01974706 39.98739166 49.95503625]
# cost:0.0025005714125647255
# m:9.967753985158238
# b:0.11641834518386818
# iteration:913
# m_current*x+b_current:[10.08417233 20.05192632 30.0196803  39.98743429 49.95518827]
# cost:0.0024836913219944004
# m:9.967863007712394
# b:0.11602473917069657
# iteration:914
# m_current*x+b_current:[10.08388775 20.05175075 30.01961376 39.98747677 49.95533978]
# cost:0.0024669251803624208
# m:9.967971661665425
# b:0.11563246392453899
# iteration:915
# m_current*x+b_current:[10.08360413 20.05157579 30.01954745 39.98751911 49.95549077]
# cost:0.0024502722184572448
# m:9.96807994826356
# b:0.1152415149461227
# iteration:916
# m_current*x+b_current:[10.08332146 20.05140141 30.01948136 39.98756131 49.95564126]
# cost:0.0024337316722598153
# m:9.968187868748808
# b:0.11485188775138667
# iteration:917
# m_current*x+b_current:[10.08303976 20.05122763 30.01941549 39.98760336 49.95579123]
# cost:0.002417302782908856
# m:9.968295424358988
# b:0.11446357787143047
# iteration:918
# m_current*x+b_current:[10.082759   20.05105443 30.01934985 39.98764528 49.9559407 ]
# cost:0.0024009847966651957
# m:9.968402616327724
# b:0.11407658085246256
# iteration:919
# m_current*x+b_current:[10.0824792  20.05088181 30.01928443 39.98768705 49.95608966]
# cost:0.00238477696487833
# m:9.968509445884477
# b:0.11369089225574987
# iteration:920
# m_current*x+b_current:[10.08220034 20.05070978 30.01921923 39.98772868 49.95623812]
# cost:0.0023686785439515612
# m:9.968615914254547
# b:0.11330650765756628
# iteration:921
# m_current*x+b_current:[10.08192242 20.05053834 30.01915425 39.98777016 49.95638608]
# cost:0.002352688795307367
# m:9.968722022659094
# b:0.1129234226491421
# iteration:922
# m_current*x+b_current:[10.08164545 20.05036747 30.01908949 39.98781151 49.95653354]
# cost:0.0023368069853540517
# m:9.968827772315144
# b:0.11254163283661364
# iteration:923
# m_current*x+b_current:[10.08136941 20.05019718 30.01902495 39.98785272 49.95668049]
# cost:0.0023210323854528955
# m:9.968933164435615
# b:0.11216113384097268
# iteration:924
# m_current*x+b_current:[10.0810943  20.05002746 30.01896063 39.98789379 49.95682696]
# cost:0.002305364271882278
# m:9.969038200229322
# b:0.11178192129801633
# iteration:925
# m_current*x+b_current:[10.08082012 20.04985832 30.01889652 39.98793472 49.95697292]
# cost:0.002289801925807775
# m:9.969142880900991
# b:0.11140399085829664
# iteration:926
# m_current*x+b_current:[10.08054687 20.04968975 30.01883263 39.98797551 49.9571184 ]
# cost:0.0022743446332458726
# m:9.969247207651275
# b:0.11102733818707122
# iteration:927
# m_current*x+b_current:[10.08027455 20.04952175 30.01876896 39.98801617 49.95726338]
# cost:0.002258991685033854
# m:9.969351181676771
# b:0.11065195896425328
# iteration:928
# m_current*x+b_current:[10.08000314 20.04935432 30.0187055  39.98805669 49.95740787]
# cost:0.0022437423767960093
# m:9.969454804170025
# b:0.11027784888436194
# iteration:929
# m_current*x+b_current:[10.07973265 20.04918746 30.01864226 39.98809707 49.95755187]
# cost:0.0022285960089113194
# m:9.969558076319558
# b:0.10990500365647314
# iteration:930
# m_current*x+b_current:[10.07946308 20.04902116 30.01857923 39.98813731 49.95769539]
# cost:0.0022135518864814297
# m:9.969660999309866
# b:0.10953341900417021
# iteration:931
# m_current*x+b_current:[10.07919442 20.04885542 30.01851642 39.98817742 49.95783842]
# cost:0.0021986093192994704
# m:9.969763574321446
# b:0.10916309066549483
# iteration:932
# m_current*x+b_current:[10.07892666 20.04869024 30.01845381 39.98821739 49.95798096]
# cost:0.002183767621816975
# m:9.969865802530798
# b:0.10879401439289817
# iteration:933
# m_current*x+b_current:[10.07865982 20.04852562 30.01839142 39.98825722 49.95812303]
# cost:0.0021690261131139302
# m:9.969967685110449
# b:0.10842618595319232
# iteration:934
# m_current*x+b_current:[10.07839387 20.04836156 30.01832924 39.98829693 49.95826461]
# cost:0.0021543841168668388
# m:9.97006922322896
# b:0.10805960112750156
# iteration:935
# m_current*x+b_current:[10.07812882 20.04819805 30.01826727 39.98833649 49.95840572]
# cost:0.0021398409613171895
# m:9.970170418050937
# b:0.10769425571121398
# iteration:936
# m_current*x+b_current:[10.07786467 20.04803509 30.01820551 39.98837593 49.95854635]
# cost:0.002125395979241595
# m:9.970271270737058
# b:0.10733014551393344
# iteration:937
# m_current*x+b_current:[10.07760142 20.04787269 30.01814396 39.98841523 49.9586865 ]
# cost:0.0021110485079207076
# m:9.970371782444069
# b:0.10696726635943128
# iteration:938
# m_current*x+b_current:[10.07733905 20.04771083 30.01808261 39.9884544  49.95882618]
# cost:0.0020967978891090733
# m:9.970471954324807
# b:0.10660561408559853
# iteration:939
# m_current*x+b_current:[10.07707757 20.04754952 30.01802148 39.98849343 49.95896539]
# cost:0.0020826434690041037
# m:9.970571787528213
# b:0.10624518454439809
# iteration:940
# m_current*x+b_current:[10.07681697 20.04738876 30.01796055 39.98853233 49.95910412]
# cost:0.0020685845982172956
# m:9.970671283199342
# b:0.10588597360181734
# iteration:941
# m_current*x+b_current:[10.07655726 20.04722854 30.01789982 39.98857111 49.95924239]
# cost:0.0020546206317436267
# m:9.970770442479377
# b:0.10552797713782046
# iteration:942
# m_current*x+b_current:[10.07629842 20.04706886 30.0178393  39.98860975 49.95938019]
# cost:0.0020407509289320624
# m:9.970869266505645
# b:0.1051711910463014
# iteration:943
# m_current*x+b_current:[10.07604046 20.04690972 30.01777899 39.98864826 49.95951752]
# cost:0.0020269748534564387
# m:9.970967756411625
# b:0.10481561123503667
# iteration:944
# m_current*x+b_current:[10.07578337 20.04675112 30.01771888 39.98868664 49.95965439]
# cost:0.002013291773285916
# m:9.971065913326965
# b:0.10446123362563843
# iteration:945
# m_current*x+b_current:[10.07552715 20.04659306 30.01765897 39.98872489 49.9597908 ]
# cost:0.001999701060656413
# m:9.971163738377495
# b:0.10410805415350777
# iteration:946
# m_current*x+b_current:[10.07527179 20.04643553 30.01759927 39.98876301 49.95992675]
# cost:0.001986202092041679
# m:9.971261232685235
# b:0.10375606876778792
# iteration:947
# m_current*x+b_current:[10.0750173  20.04627853 30.01753977 39.988801   49.96006223]
# cost:0.0019727942481239566
# m:9.971358397368416
# b:0.1034052734313181
# iteration:948
# m_current*x+b_current:[10.07476367 20.04612207 30.01748047 39.98883886 49.96019726]
# cost:0.0019594769137668867
# m:9.971455233541485
# b:0.10305566412058675
# iteration:949
# m_current*x+b_current:[10.0745109  20.04596613 30.01742136 39.9888766  49.96033183]
# cost:0.0019462494779860847
# m:9.971551742315123
# b:0.10270723682568589
# iteration:950
# m_current*x+b_current:[10.07425898 20.04581072 30.01736246 39.98891421 49.96046595]
# cost:0.001933111333922084
# m:9.971647924796255
# b:0.10235998755026478
# iteration:951
# m_current*x+b_current:[10.07400791 20.04565584 30.01730376 39.98895169 49.96059961]
# cost:0.00192006187881159
# m:9.971743782088062
# b:0.10201391231148418
# iteration:952
# m_current*x+b_current:[10.07375769 20.04550148 30.01724526 39.98898904 49.96073282]
# cost:0.00190710051396021
# m:9.97183931529
# b:0.10166900713997078
# iteration:953
# m_current*x+b_current:[10.07350832 20.04534764 30.01718695 39.98902627 49.96086558]
# cost:0.0018942266447155897
# m:9.971934525497801
# b:0.10132526807977141
# iteration:954
# m_current*x+b_current:[10.07325979 20.04519432 30.01712884 39.98906337 49.9609979 ]
# cost:0.0018814396804391399
# m:9.972029413803499
# b:0.10098269118830794
# iteration:955
# m_current*x+b_current:[10.0730121  20.04504152 30.01707093 39.98910035 49.96112976]
# cost:0.001868739034479195
# m:9.97212398129543
# b:0.10064127253633186
# iteration:956
# m_current*x+b_current:[10.07276525 20.04488924 30.01701322 39.9891372  49.96126118]
# cost:0.001856124124144775
# m:9.972218229058257
# b:0.1003010082078794
# iteration:957
# m_current*x+b_current:[10.07251924 20.04473747 30.0169557  39.98917392 49.96139215]
# cost:0.001843594370678094
# m:9.972312158172967
# b:0.09996189430022644
# iteration:958
# m_current*x+b_current:[10.07227405 20.04458621 30.01689837 39.98921053 49.96152269]
# cost:0.001831149199228167
# m:9.9724057697169
# b:0.09962392692384389
# iteration:959
# m_current*x+b_current:[10.0720297  20.04443547 30.01684124 39.98924701 49.96165278]
# cost:0.0018187880388247633
# m:9.97249906476375
# b:0.09928710220235298
# iteration:960
# m_current*x+b_current:[10.07178617 20.04428523 30.0167843  39.98928336 49.96178243]
# cost:0.0018065103223519467
# m:9.972592044383584
# b:0.09895141627248086
# iteration:961
# m_current*x+b_current:[10.07154346 20.04413551 30.01672755 39.98931959 49.96191164]
# cost:0.001794315486521981
# m:9.972684709642847
# b:0.09861686528401625
# iteration:962
# m_current*x+b_current:[10.07130157 20.04398628 30.01667099 39.9893557  49.96204041]
# cost:0.0017822029718496714
# m:9.97277706160438
# b:0.09828344539976513
# iteration:963
# m_current*x+b_current:[10.07106051 20.04383757 30.01661463 39.98939169 49.96216875]
# cost:0.0017701722226262382
# m:9.97286910132743
# b:0.09795115279550709
# iteration:964
# m_current*x+b_current:[10.07082025 20.04368936 30.01655846 39.98942756 49.96229666]
# cost:0.0017582226868950942
# m:9.972960829867665
# b:0.09761998365995116
# iteration:965
# m_current*x+b_current:[10.07058081 20.04354164 30.01650247 39.9894633  49.96242413]
# cost:0.0017463538164245987
# m:9.973052248277181
# b:0.09728993419469223
# iteration:966
# m_current*x+b_current:[10.07034218 20.04339443 30.01644668 39.98949893 49.96255118]
# cost:0.0017345650666848681
# m:9.97314335760452
# b:0.09696100061416753
# iteration:967
# m_current*x+b_current:[10.07010436 20.04324772 30.01639107 39.98953443 49.96267779]
# cost:0.0017228558968213116
# m:9.973234158894677
# b:0.09663317914561297
# iteration:968
# m_current*x+b_current:[10.06986734 20.0431015  30.01633566 39.98956981 49.96280397]
# cost:0.0017112257696305902
# m:9.973324653189112
# b:0.09630646602902011
# iteration:969
# m_current*x+b_current:[10.06963112 20.04295577 30.01628043 39.98960508 49.96292973]
# cost:0.0016996741515353739
# m:9.973414841525766
# b:0.09598085751709302
# iteration:970
# m_current*x+b_current:[10.0693957  20.04281054 30.01622538 39.98964022 49.96305507]
# cost:0.0016882005125608323
# m:9.973504724939072
# b:0.09565634987520519
# iteration:971
# m_current*x+b_current:[10.06916107 20.0426658  30.01617052 39.98967525 49.96317997]
# cost:0.001676804326309323
# m:9.973594304459963
# b:0.09533293938135672
# iteration:972
# m_current*x+b_current:[10.06892724 20.04252155 30.01611585 39.98971016 49.96330446]
# cost:0.0016654850699365936
# m:9.973683581115889
# b:0.09501062232613176
# iteration:973
# m_current*x+b_current:[10.0686942  20.04237778 30.01606137 39.98974495 49.96342853]
# cost:0.0016542422241283981
# m:9.973772555930825
# b:0.09468939501265579
# iteration:974
# m_current*x+b_current:[10.06846195 20.04223451 30.01600706 39.98977962 49.96355217]
# cost:0.0016430752730754981
# m:9.973861229925284
# b:0.09436925375655317
# iteration:975
# m_current*x+b_current:[10.06823048 20.04209171 30.01595294 39.98981417 49.9636754 ]
# cost:0.0016319837044507946
# m:9.973949604116328
# b:0.09405019488590508
# iteration:976
# m_current*x+b_current:[10.0679998  20.0419494  30.01589901 39.98984861 49.96379822]
# cost:0.001620967009385873
# m:9.974037679517581
# b:0.09373221474120731
# iteration:977
# m_current*x+b_current:[10.06776989 20.04180757 30.01584525 39.98988293 49.96392061]
# cost:0.0016100246824472166
# m:9.974125457139241
# b:0.09341530967532828
# iteration:978
# m_current*x+b_current:[10.06754077 20.04166622 30.01579168 39.98991714 49.9640426 ]
# cost:0.0015991562216131515
# m:9.974212937988089
# b:0.09309947605346726
# iteration:979
# m_current*x+b_current:[10.06731241 20.04152535 30.01573829 39.98995123 49.96416417]
# cost:0.001588361128251174
# m:9.9743001230675
# b:0.0927847102531126
# iteration:980
# m_current*x+b_current:[10.06708483 20.04138496 30.01568508 39.9899852  49.96428533]
# cost:0.0015776389070946582
# m:9.974387013377463
# b:0.0924710086640003
# iteration:981
# m_current*x+b_current:[10.06685802 20.04124504 30.01563205 39.99001906 49.96440608]
# cost:0.0015669890662201851
# m:9.97447360991458
# b:0.09215836768807253
# iteration:982
# m_current*x+b_current:[10.06663198 20.04110559 30.0155792  39.99005281 49.96452642]
# cost:0.0015564111170251744
# m:9.974559913672088
# b:0.09184678373943625
# iteration:983
# m_current*x+b_current:[10.0664067  20.04096661 30.01552652 39.99008644 49.96464635]
# cost:0.001545904574205424
# m:9.974645925639862
# b:0.09153625324432225
# iteration:984
# m_current*x+b_current:[10.06618218 20.0408281  30.01547403 39.99011996 49.96476588]
# cost:0.001535468955732594
# m:9.974731646804432
# b:0.09122677264104409
# iteration:985
# m_current*x+b_current:[10.06595842 20.04069007 30.01542171 39.99015336 49.96488501]
# cost:0.0015251037828323667
# m:9.974817078148995
# b:0.09091833837995729
# iteration:986
# m_current*x+b_current:[10.06573542 20.04055249 30.01536957 39.99018665 49.96500373]
# cost:0.0015148085799623714
# m:9.97490222065342
# b:0.09061094692341846
# iteration:987
# m_current*x+b_current:[10.06551317 20.04041539 30.01531761 39.99021983 49.96512205]
# cost:0.0015045828747903339
# m:9.974987075294262
# b:0.09030459474574493
# iteration:988
# m_current*x+b_current:[10.06529167 20.04027875 30.01526582 39.9902529  49.96523997]
# cost:0.0014944261981725733
# m:9.97507164304478
# b:0.08999927833317428
# iteration:989
# m_current*x+b_current:[10.06507092 20.04014256 30.01521421 39.99028585 49.96535749]
# cost:0.0014843380841322918
# m:9.975155924874938
# b:0.08969499418382401
# iteration:990
# m_current*x+b_current:[10.06485092 20.04000684 30.01516277 39.99031869 49.96547462]
# cost:0.001474318069838326
# m:9.975239921751422
# b:0.08939173880765124
# iteration:991
# m_current*x+b_current:[10.06463166 20.03987158 30.0151115  39.99035143 49.96559135]
# cost:0.0014643656955836306
# m:9.97532363463765
# b:0.0890895087264129
# iteration:992
# m_current*x+b_current:[10.06441314 20.03973678 30.01506041 39.99038405 49.96570768]
# cost:0.0014544805047647681
# m:9.975407064493783
# b:0.08878830047362565
# iteration:993
# m_current*x+b_current:[10.06419536 20.03960243 30.01500949 39.99041656 49.96582362]
# cost:0.001444662043860379
# m:9.975490212276734
# b:0.08848811059452616
# iteration:994
# m_current*x+b_current:[10.06397832 20.03946854 30.01495875 39.99044896 49.96593917]
# cost:0.001434909862410433
# m:9.975573078940181
# b:0.08818893564603163
# iteration:995
# m_current*x+b_current:[10.06376201 20.03933509 30.01490817 39.99048125 49.96605433]
# cost:0.0014252235129959487
# m:9.97565566543458
# b:0.08789077219670013
# iteration:996
# m_current*x+b_current:[10.06354644 20.0392021  30.01485777 39.99051343 49.9661691 ]
# cost:0.0014156025512184383
# m:9.97573797270717
# b:0.08759361682669131
# iteration:997
# m_current*x+b_current:[10.06333159 20.03906956 30.01480753 39.99054551 49.96628348]
# cost:0.001406046535678859
# m:9.975820001701992
# b:0.08729746612772724
# iteration:998
# m_current*x+b_current:[10.06311747 20.03893747 30.01475747 39.99057747 49.96639747]
# cost:0.0013965550279581528
# m:9.97590175335989
# b:0.08700231670305315
# iteration:999
# m_current*x+b_current:[10.06290407 20.03880582 30.01470758 39.99060933 49.96651108]
# cost:0.0013871275925969042
